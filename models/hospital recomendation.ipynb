# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score
# import geopy as gp
from geopy.distance import geodesic

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\hospital_dataset_1000 (1).csv")
print(df)
# Out:
#                   id                 City           State           District  \
# 0        Hospital #0             Anantpur  Andhra Pradesh      Ananthapuramu
# 1        Hospital #1             Anantpur  Andhra Pradesh      Ananthapuramu
# 2        Hospital #2              Chitoor  Andhra Pradesh           Chittoor
# 3        Hospital #3             Chittoor  Andhra Pradesh           Chittoor
# 4        Hospital #4        East Godavari  Andhra Pradesh      East Godavari
# ...              ...                  ...             ...                ...
# 2561  Hospital #2552            Medinipur     West Bengal  Paschim Medinipur
# 2562  Hospital #2553            Medinipur     West Bengal  Paschim Medinipur
# 2563  Hospital #2554  North 24 \nParganas     West Bengal  North 24 Parganas
# 2564  Hospital #2555            Serampore     West Bengal            Hooghly
# 2565  Hospital #2556             Siliguri     West Bengal         Darjeeling
#
#        Density   Latitude  Longitude  Rating  Number of Reviews
# 0      219.608  14.696533  77.584570     4.1                229
# 1      219.608  14.660635  77.579342     4.9              19172
# 2      273.230  13.229217  79.084472     3.9                139
# 3      273.230  13.303435  78.972117     4.0                 92
# 4      715.460  16.970995  82.230396     4.8               8090
# ...        ...        ...        ...     ...                ...
# 2561   757.000  22.408188  87.739743     4.1                348
# 2562   757.000  22.973985  88.397298     3.8                121
# 2563  2463.000  22.887347  88.454171     4.1                141
# 2564  1753.000  22.686490  88.298755     3.3                170
# 2565   762.000  26.704812  88.415618     3.5                260
#
# [2566 rows x 9 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       3 df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\hospital_dataset_1000 (1).csv")
#       4 print(df)
#
# File c:\Users\hp\New folder\Lib\site-packages\pandas\__init__.py:26
#      22 del _hard_dependencies, _dependency, _missing_dependencies
#      24 try:
#      25     # numpy compat
# ---> 26     from pandas.compat import (
#      27         is_numpy_dev as _is_numpy_dev,  # pyright: ignore[reportUnusedImport] # noqa: F401
#      28     )
#      29 except ImportError as _err:  # pragma: no cover
#      30     _module = _err.name
#
# File c:\Users\hp\New folder\Lib\site-packages\pandas\compat\__init__.py:27
#      25 import pandas.compat.compressors
#      26 from pandas.compat.numpy import is_numpy_dev
# ---> 27 from pandas.compat.pyarrow import (
#      28     pa_version_under10p1,
#      29     pa_version_under11p0,
#      30     pa_version_under13p0,
#      31     pa_version_under14p0,
#      32     pa_version_under14p1,
#      33     pa_version_under16p0,
#      34     pa_version_under17p0,
#      35 )
#      37 if TYPE_CHECKING:
#      38     from pandas._typing import F
#
# File c:\Users\hp\New folder\Lib\site-packages\pandas\compat\pyarrow.py:8
#       5 from pandas.util.version import Version
#       7 try:
# ----> 8     import pyarrow as pa
#      10     _palv = Version(Version(pa.__version__).base_version)
#      11     pa_version_under10p1 = _palv < Version("10.0.1")
#
# File c:\Users\hp\New folder\Lib\site-packages\pyarrow\__init__.py:65
#      63 _gc_enabled = _gc.isenabled()
#      64 _gc.disable()
# ---> 65 import pyarrow.lib as _lib
#      66 if _gc_enabled:
#      67     _gc.enable()
#
# File <frozen importlib._bootstrap>:645, in parent(self)
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:3419, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3414     self.history_manager.store_output(execution_count)
#    3415     if result.error_in_exec:
#    3416         # Store formatted traceback and error details
#    3417         self.history_manager.exceptions[
#    3418             execution_count
# -> 3419         ] = self._format_exception_for_storage(result.error_in_exec)
#    3421 return result
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:3469, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3466         stb = evalue._render_traceback_()
#    3467     else:
#    3468         # Otherwise, use InteractiveTB to format the traceback.
# -> 3469         stb = self.InteractiveTB.structured_traceback(
#    3470             etype, evalue, tb, tb_offset=1
#    3471         )
#    3472 except Exception:
#    3473     # In case formatting fails, fallback to Python's built-in formatting.
#    3474     stb = traceback.format_exception(etype, evalue, tb)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\ultratb.py:1193, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1191 else:
#    1192     self.tb = etb
# -> 1193 return FormattedTB.structured_traceback(
#    1194     self, etype, evalue, etb, tb_offset, context
#    1195 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\ultratb.py:1064, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1061 mode = self.mode
#    1062 if mode in self.verbose_modes:
#    1063     # Verbose modes need a full traceback
# -> 1064     return VerboseTB.structured_traceback(
#    1065         self, etype, evalue, etb, tb_offset, context
#    1066     )
#    1067 elif mode == "Docs":
#    1068     # return DocTB
#    1069     return DocTB(
#    1070         theme_name=self._theme_name,
#    1071         call_pdb=self.call_pdb,
#    (...)   1079         etype, evalue, etb, tb_offset, 1
#    1080     )  # type: ignore[arg-type]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\ultratb.py:872, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     863 def structured_traceback(
#     864     self,
#     865     etype: type,
#    (...)    869     context: int = 5,
#     870 ) -> list[str]:
#     871     """Return a nice text document describing the traceback."""
# --> 872     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     873         etype, evalue, etb, context, tb_offset
#     874     )
#     876     termsize = min(75, get_terminal_size()[0])
#     877     theme = theme_table[self._theme_name]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\ultratb.py:757, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     755 assert isinstance(tb_offset, int)
#     756 head = self.prepare_header(str(etype), self.long_header)
# --> 757 records = self.get_records(etb, context, tb_offset) if etb else []
#     759 frames = []
#     760 skipped = 0
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\ultratb.py:830, in VerboseTB.get_records(self, etb, context, tb_offset)
#     828 while cf is not None:
#     829     try:
# --> 830         mod = inspect.getmodule(cf.tb_frame)
#     831         if mod is not None:
#     832             mod_name = mod.__name__
#
# File c:\Users\hp\New folder\Lib\inspect.py:1012, in getmodule(object, _filename)
#    1010 # Try the cache again with the absolute file name
#    1011 try:
# -> 1012     file = getabsfile(object, _filename)
#    1013 except (TypeError, FileNotFoundError):
#    1014     return None
#
# File c:\Users\hp\New folder\Lib\inspect.py:994, in getabsfile(object, _filename)
#     989 """Return an absolute path to the source or compiled file for an object.
#     990
#     991 The idea is for each object to have a unique origin, so this routine
#     992 normalizes the result as much as possible."""
#     993 if _filename is None:
# --> 994     _filename = getsourcefile(object) or getfile(object)
#     995 return os.path.normcase(os.path.abspath(_filename))
#
# File c:\Users\hp\New folder\Lib\inspect.py:979, in getsourcefile(object)
#     977 if filename in linecache.cache:
#     978     return filename
# --> 979 if os.path.exists(filename):
#     980     return filename
#     981 # only return a non-existent filename if the module has a PEP 302 loader
#
# KeyboardInterrupt:

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['spec_encoded'] = le.fit_transform(df['Number of Reviews'])

# %%
from sklearn.ensemble import RandomForestClassifier

X = df['spec_encoded'].values.reshape(-1, 1)
y = df['Number of Reviews'].values

model = RandomForestClassifier()
model.fit(X, y)
# Out:
# RandomForestClassifier()

# %%
from geopy.distance import geodesic

def find_nearest(lat, lon, hospitals):
    distances = []
    
    for i, row in hospitals.iterrows():
        hospital_loc = (row['latitude'], row['longitude'])
        patient_loc = (lat, lon)
        
        dist = geodesic(patient_loc, hospital_loc).km
        distances.append(dist)
    
    hospitals['distance'] = distances
    return hospitals.sort_values(by='distance')
